# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from sklearn.metrics import r2_score
from scipy.interpolate import make_interp_spline

x = [0,2,4,6,8,12,16]
y = [149.71,117.43,112.96,106.68,119.65-15,104.13-10,97.18-12]
x=[x[i]*5.3/1e3/2.7 for i in range(len(x))]
for i in range(len(y)):
    y[i]=np.log(y[i])
    
    
p, cov=np.polyfit(x, y, 1, cov=True)
mymodel = np.poly1d(p)
myline = np.linspace(0, 4e-2, 1000)
a1 = mymodel.coefficients[0]
a0 = mymodel.coefficients[1]

r2=r2_score(y, mymodel(x))
print("R2=%f"%r2)
# print("the values are %d %7.5f %s" % (x, y, z))
#print(mymodel.coefficients)

#print(np.sqrt(np.diag(cov)))
sigma1,sigma0=np.sqrt(np.diag(cov))

#x_smooth = np.linspace(x.min(), x.max(), 300)
#y_smooth = make_interp_spline(x, y)(x_smooth)


plt.figure(figsize=(12,9))
#plt.title(r"$\rm P_{LD} - I$ Distribution", fontsize=18)
#plt.errorbar(x, y, yerr=y_err,fmt='o', label='data', color='blue', markersize=5, ecolor='blue', capsize=3)
plt.xlabel(r'x/cm', fontsize=18, color="black") 
plt.ylabel(r'$\ln{I}$', fontsize=18, color="black") 
plt.scatter(x, y, color="blue", label='data')
plt.plot(myline, mymodel(myline), color = 'green', linestyle='dashed', label='Linear Fit')
plt.grid(True)
#plt.axis([30, 400, 100, 400])
#plt.figure()
plt.legend(loc=0, frameon=False, fontsize=20)

ax=plt.gca()
#x_major_locator=MultipleLocator(2)
#y_major_locator=MultipleLocator(1)
#ax.xaxis.set_major_locator(x_major_locator)
#ax.yaxis.set_major_locator(y_major_locator)
plt.xlim(0,0.04)
#plt.ylim(0,5)

plt.text(0.018, 4.8,r"$I=I_0 exp(-\mu_0 x)$", fontsize=18,color="green")
plt.text(0.018, 4.75, r"$\mu_0=(%f\pm%f)\rm cm^{-1}$"%(-a1,sigma1), fontsize=18,color="green")
#plt.text(5, 4.5, r"$\sigma=%f\pm%f$"%(a0/a1,np.sqrt((sigma0/a1)**2+(a0/a1/a1*sigma1)**2)), fontsize=18,color="green")
#plt.text(5, 4.0, r"$R^2=%f$"%r2, fontsize=18, color="green")

plt.savefig('./phyex2_fig1.pdf')
plt.show()
# Out:
# R2=0.880061

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from sklearn.metrics import r2_score
from scipy.interpolate import make_interp_spline

x = [0,2,4,6,8]
y = [359.54,321.18,286.55,258.76,230.84]
x=[x[i]*5.3/1e3/2.7 for i in range(len(x))]
for i in range(len(y)):
    y[i]=np.log(y[i])
    
    
p, cov=np.polyfit(x, y, 1, cov=True)
mymodel = np.poly1d(p)
myline = np.linspace(0, 2e-2, 1000)
a1 = mymodel.coefficients[0]
a0 = mymodel.coefficients[1]

r2=r2_score(y, mymodel(x))
print("R2=%f"%r2)
# print("the values are %d %7.5f %s" % (x, y, z))
#print(mymodel.coefficients)

#print(np.sqrt(np.diag(cov)))
sigma1,sigma0=np.sqrt(np.diag(cov))

#x_smooth = np.linspace(x.min(), x.max(), 300)
#y_smooth = make_interp_spline(x, y)(x_smooth)


plt.figure(figsize=(12,9))
#plt.title(r"$\rm P_{LD} - I$ Distribution", fontsize=18)
#plt.errorbar(x, y, yerr=y_err,fmt='o', label='data', color='blue', markersize=5, ecolor='blue', capsize=3)
plt.xlabel(r'x/cm', fontsize=18, color="black") 
plt.ylabel(r'$\ln{I}$', fontsize=18, color="black") 
plt.scatter(x, y, color="blue", label='data')
plt.plot(myline, mymodel(myline), color = 'green', linestyle='dashed', label='Linear Fit')
plt.grid(True)
#plt.axis([30, 400, 100, 400])
#plt.figure()
plt.legend(loc=0, frameon=False, fontsize=20)

ax=plt.gca()
#x_major_locator=MultipleLocator(2)
#y_major_locator=MultipleLocator(1)
#ax.xaxis.set_major_locator(x_major_locator)
#ax.yaxis.set_major_locator(y_major_locator)
plt.xlim(0,0.02)
#plt.ylim(0,5)

plt.text(0.008, 5.8,r"$I=I_0 exp(-\mu_0 x)$", fontsize=18,color="green")
plt.text(0.008, 5.75, r"$\mu_0=(%f\pm%f)\rm cm^{-1}$"%(-a1,sigma1), fontsize=18,color="green")
#plt.text(5, 4.5, r"$\sigma=%f\pm%f$"%(a0/a1,np.sqrt((sigma0/a1)**2+(a0/a1/a1*sigma1)**2)), fontsize=18,color="green")
#plt.text(5, 4.0, r"$R^2=%f$"%r2, fontsize=18, color="green")

plt.savefig('./phyex2_fig2.pdf')
plt.show()
# Out:
# R2=0.999685

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from sklearn.metrics import r2_score
from scipy.interpolate import make_interp_spline

x = [0,2,4,6,8]
y = [513.89,314.47,199.92,126.10,78.66]
x=[x[i]*5.3/1e3/2.7 for i in range(len(x))]
for i in range(len(y)):
    y[i]=np.log(y[i])
    
    
p, cov=np.polyfit(x, y, 1, cov=True)
mymodel = np.poly1d(p)
myline = np.linspace(0, 2e-2, 1000)
a1 = mymodel.coefficients[0]
a0 = mymodel.coefficients[1]

r2=r2_score(y, mymodel(x))
print("R2=%f"%r2)
# print("the values are %d %7.5f %s" % (x, y, z))
#print(mymodel.coefficients)

#print(np.sqrt(np.diag(cov)))
sigma1,sigma0=np.sqrt(np.diag(cov))

#x_smooth = np.linspace(x.min(), x.max(), 300)
#y_smooth = make_interp_spline(x, y)(x_smooth)


plt.figure(figsize=(12,9))
#plt.title(r"$\rm P_{LD} - I$ Distribution", fontsize=18)
#plt.errorbar(x, y, yerr=y_err,fmt='o', label='data', color='blue', markersize=5, ecolor='blue', capsize=3)
plt.xlabel(r'x/cm', fontsize=18, color="black") 
plt.ylabel(r'$\ln{I}$', fontsize=18, color="black") 
plt.scatter(x, y, color="blue", label='data')
plt.plot(myline, mymodel(myline), color = 'green', linestyle='dashed', label='Linear Fit')
plt.grid(True)
#plt.axis([30, 400, 100, 400])
#plt.figure()
plt.legend(loc=0, frameon=False, fontsize=20)

ax=plt.gca()
#x_major_locator=MultipleLocator(2)
#y_major_locator=MultipleLocator(1)
#ax.xaxis.set_major_locator(x_major_locator)
#ax.yaxis.set_major_locator(y_major_locator)
plt.xlim(0,0.02)
#plt.ylim(0,5)

plt.text(0.008, 5.8,r"$I=I_0 exp(-\mu_0 x)$", fontsize=18,color="green")
plt.text(0.008, 5.65, r"$\mu_0=(%f\pm%f)\rm cm^{-1}$"%(-a1,sigma1), fontsize=18,color="green")
#plt.text(5, 4.5, r"$\sigma=%f\pm%f$"%(a0/a1,np.sqrt((sigma0/a1)**2+(a0/a1/a1*sigma1)**2)), fontsize=18,color="green")
#plt.text(5, 4.0, r"$R^2=%f$"%r2, fontsize=18, color="green")

plt.savefig('./phyex2_fig3.pdf')
plt.show()
# Out:
# R2=0.999846

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from sklearn.metrics import r2_score
from scipy.interpolate import make_interp_spline

x = [0,1,2,3,4]
y = [278.44,192.04,134.35,98.56,68.46]
x=[x[i]*5.3/1e3/2.7 for i in range(len(x))]
for i in range(len(y)):
    y[i]=np.log(y[i])
    
    
p, cov=np.polyfit(x, y, 1, cov=True)
mymodel = np.poly1d(p)
myline = np.linspace(0, 1e-2, 1000)
a1 = mymodel.coefficients[0]
a0 = mymodel.coefficients[1]

r2=r2_score(y, mymodel(x))
print("R2=%f"%r2)
# print("the values are %d %7.5f %s" % (x, y, z))
#print(mymodel.coefficients)

#print(np.sqrt(np.diag(cov)))
sigma1,sigma0=np.sqrt(np.diag(cov))

#x_smooth = np.linspace(x.min(), x.max(), 300)
#y_smooth = make_interp_spline(x, y)(x_smooth)


plt.figure(figsize=(12,9))
#plt.title(r"$\rm P_{LD} - I$ Distribution", fontsize=18)
#plt.errorbar(x, y, yerr=y_err,fmt='o', label='data', color='blue', markersize=5, ecolor='blue', capsize=3)
plt.xlabel(r'x/cm', fontsize=18, color="black") 
plt.ylabel(r'$\ln{I}$', fontsize=18, color="black") 
plt.scatter(x, y, color="blue", label='data')
plt.plot(myline, mymodel(myline), color = 'green', linestyle='dashed', label='Linear Fit')
plt.grid(True)
#plt.axis([30, 400, 100, 400])
#plt.figure()
plt.legend(loc=0, frameon=False, fontsize=20)

ax=plt.gca()
#x_major_locator=MultipleLocator(2)
#y_major_locator=MultipleLocator(1)
#ax.xaxis.set_major_locator(x_major_locator)
#ax.yaxis.set_major_locator(y_major_locator)
plt.xlim(0,0.01)
#plt.ylim(0,5)

plt.text(0.005, 5.3,r"$I=I_0 exp(-\mu_0 x)$", fontsize=18,color="green")
plt.text(0.005, 5.15, r"$\mu_0=(%f\pm%f)\rm cm^{-1}$"%(-a1,sigma1), fontsize=18,color="green")
#plt.text(5, 4.5, r"$\sigma=%f\pm%f$"%(a0/a1,np.sqrt((sigma0/a1)**2+(a0/a1/a1*sigma1)**2)), fontsize=18,color="green")
#plt.text(5, 4.0, r"$R^2=%f$"%r2, fontsize=18, color="green")

plt.savefig('./phyex2_fig4.pdf')
plt.show()
# Out:
# R2=0.999165

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from sklearn.metrics import r2_score
from scipy.interpolate import make_interp_spline

x = [0,1,2,3,4]
y = [244.90,143.48,83.59,51.71,33.25]
x=[x[i]*5.3/1e3/2.7 for i in range(len(x))]
for i in range(len(y)):
    y[i]=np.log(y[i])
    
    
p, cov=np.polyfit(x, y, 1, cov=True)
mymodel = np.poly1d(p)
myline = np.linspace(0, 1e-2, 1000)
a1 = mymodel.coefficients[0]
a0 = mymodel.coefficients[1]

r2=r2_score(y, mymodel(x))
print("R2=%f"%r2)
# print("the values are %d %7.5f %s" % (x, y, z))
#print(mymodel.coefficients)

#print(np.sqrt(np.diag(cov)))
sigma1,sigma0=np.sqrt(np.diag(cov))

#x_smooth = np.linspace(x.min(), x.max(), 300)
#y_smooth = make_interp_spline(x, y)(x_smooth)


plt.figure(figsize=(12,9))
#plt.title(r"$\rm P_{LD} - I$ Distribution", fontsize=18)
#plt.errorbar(x, y, yerr=y_err,fmt='o', label='data', color='blue', markersize=5, ecolor='blue', capsize=3)
plt.xlabel(r'x/cm', fontsize=18, color="black") 
plt.ylabel(r'$\ln{I}$', fontsize=18, color="black") 
plt.scatter(x, y, color="blue", label='data')
plt.plot(myline, mymodel(myline), color = 'green', linestyle='dashed', label='Linear Fit')
plt.grid(True)
#plt.axis([30, 400, 100, 400])
#plt.figure()
plt.legend(loc=0, frameon=False, fontsize=20)

ax=plt.gca()
#x_major_locator=MultipleLocator(2)
#y_major_locator=MultipleLocator(1)
#ax.xaxis.set_major_locator(x_major_locator)
#ax.yaxis.set_major_locator(y_major_locator)
plt.xlim(0,0.01)
#plt.ylim(0,5)

plt.text(0.005, 5.0,r"$I=I_0 exp(-\mu_0 x)$", fontsize=18,color="green")
plt.text(0.005, 4.8, r"$\mu_0=(%f\pm%f)\rm cm^{-1}$"%(-a1,sigma1), fontsize=18,color="green")
#plt.text(5, 4.5, r"$\sigma=%f\pm%f$"%(a0/a1,np.sqrt((sigma0/a1)**2+(a0/a1/a1*sigma1)**2)), fontsize=18,color="green")
#plt.text(5, 4.0, r"$R^2=%f$"%r2, fontsize=18, color="green")

plt.savefig('./phyex2_fig5.pdf')
plt.show()
# Out:
# R2=0.998162

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from sklearn.metrics import r2_score
from scipy.interpolate import make_interp_spline

x = [1757.23,1427.48,873.61,757.26,649.04]
y = [15.152427,28.077502,118.890740,176.923568,255.437059]
x=[3*1e8/x[i]/x[i]/x[i] for i in range(len(x))]
y=[y[i]/2.7 for i in range(len(y))]

    
p, cov=np.polyfit(x, y, 1, cov=True)
mymodel = np.poly1d(p)
myline = np.linspace(0, 1.2, 1000)
a1 = mymodel.coefficients[0]
a0 = mymodel.coefficients[1]

r2=r2_score(y, mymodel(x))
print("R2=%f"%r2)
# print("the values are %d %7.5f %s" % (x, y, z))
#print(mymodel.coefficients)

#print(np.sqrt(np.diag(cov)))
sigma1,sigma0=np.sqrt(np.diag(cov))

#x_smooth = np.linspace(x.min(), x.max(), 300)
#y_smooth = make_interp_spline(x, y)(x_smooth)


plt.figure(figsize=(12,9))
#plt.title(r"$\rm P_{LD} - I$ Distribution", fontsize=18)
#plt.errorbar(x, y, yerr=y_err,fmt='o', label='data', color='blue', markersize=5, ecolor='blue', capsize=3)
plt.xlabel(r'$\frac{Z^4}{A}\cdot\lambda^3\ /\rm\ relative\ unit$', fontsize=20, color="black") 
plt.ylabel(r'$\tau_m\ /\rm (cm^2/g)$', fontsize=18, color="black") 
plt.scatter(x, y, color="blue", label='data')
plt.plot(myline, mymodel(myline), color = 'green', linestyle='dashed', label='Linear Fit')
plt.grid(True)
#plt.axis([30, 400, 100, 400])
#plt.figure()
plt.legend(loc=0, frameon=False, fontsize=20)

ax=plt.gca()
#x_major_locator=MultipleLocator(2)
#y_major_locator=MultipleLocator(1)
#ax.xaxis.set_major_locator(x_major_locator)
#ax.yaxis.set_major_locator(y_major_locator)
plt.xlim(0,1.2)
plt.ylim(0,120)

#plt.text(0.005, 5.0,r"$I=I_0 exp(-\mu_0 x)$", fontsize=18,color="green")
#plt.text(0.005, 4.8, r"$\mu_0=(%f\pm%f)\rm cm^{-1}$"%(-a1,sigma1), fontsize=18,color="green")
#plt.text(5, 4.5, r"$\sigma=%f\pm%f$"%(a0/a1,np.sqrt((sigma0/a1)**2+(a0/a1/a1*sigma1)**2)), fontsize=18,color="green")
#plt.text(5, 4.0, r"$R^2=%f$"%r2, fontsize=18, color="green")

plt.savefig('./phyex2_fig6.pdf')
plt.show()
# Out:
# R2=0.994813
