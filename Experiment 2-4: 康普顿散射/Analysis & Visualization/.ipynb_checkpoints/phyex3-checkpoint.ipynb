# %%
with open('/Users/DaweiFu/Downloads/bkg20.dat.txt','r') as f:
    bkg20 = f.read().splitlines()
    bkg20=[int(bkg20[i]) for i in range(len(bkg20))]
print(len(bkg20))

with open('/Users/DaweiFu/Downloads/bkg40.dat.txt','r') as f:
    bkg40 = f.read().splitlines()
    bkg40=[int(bkg40[i]) for i in range(len(bkg40))]
print(len(bkg40))

with open('/Users/DaweiFu/Downloads/bkg60.dat.txt','r') as f:
    bkg60 = f.read().splitlines()
    bkg60=[int(bkg60[i]) for i in range(len(bkg60))]
print(len(bkg60))

with open('/Users/DaweiFu/Downloads/bkg80.dat.txt','r') as f:
    bkg80 = f.read().splitlines()
    bkg80=[int(bkg80[i]) for i in range(len(bkg80))]
print(len(bkg80))

with open('/Users/DaweiFu/Downloads/bkg100.dat.txt','r') as f:
    bkg100 = f.read().splitlines()
    bkg100=[int(bkg100[i]) for i in range(len(bkg100))]
print(len(bkg100))

with open('/Users/DaweiFu/Downloads/bkg120.dat.txt','r') as f:
    bkg120 = f.read().splitlines()
    bkg120=[int(bkg120[i]) for i in range(len(bkg120))]
print(len(bkg120))
# Out:
# 1024
# 1024
# 1024
# 1024
# 1024
# 1024

# %%
import numpy as np
sum=[0,0,0,0,0,0]
for i in range(397-1,457):
    sum[0]+=bkg20[i]
for i in range(323-1,385):
    sum[1]+=bkg40[i]    
for i in range(253-1,305):
    sum[2]+=bkg60[i]
for i in range(199-1,244):
    sum[3]+=bkg80[i]
for i in range(161-1,200):
    sum[4]+=bkg100[i]
for i in range(134-1,171):
    sum[5]+=bkg120[i]
    
print(sum)
# Out:
# [1023, 604, 558, 541, 677, 1021]

# %%
with open('/Users/DaweiFu/Downloads/scatter20.dat.txt','r') as f:
    scatter20 = f.read().splitlines()
    scatter20=[int(scatter20[i]) for i in range(len(scatter20))]

with open('/Users/DaweiFu/Downloads/scatter40.dat.txt','r') as f:
    scatter40 = f.read().splitlines()
    scatter40=[int(scatter40[i]) for i in range(len(scatter40))]

with open('/Users/DaweiFu/Downloads/scatter60.dat.txt','r') as f:
    scatter60 = f.read().splitlines()
    scatter60=[int(scatter60[i]) for i in range(len(scatter60))]

with open('/Users/DaweiFu/Downloads/scatter80.dat.txt','r') as f:
    scatter80 = f.read().splitlines()
    scatter80=[int(scatter80[i]) for i in range(len(scatter80))]

with open('/Users/DaweiFu/Downloads/scatter100.dat.txt','r') as f:
    scatter100 = f.read().splitlines()
    scatter100=[int(scatter100[i]) for i in range(len(scatter100))]

with open('/Users/DaweiFu/Downloads/scatter120.dat.txt','r') as f:
    scatter120 = f.read().splitlines()
    scatter120=[int(scatter120[i]) for i in range(len(scatter120))]

# %%
from numpy import array
from numpy import linspace
import matplotlib.pyplot as plt

x=[i for i in range(1024)]
peak_x = [427,350,280,223,179,153]
peak_y = [scatter20[427],scatter40[350],scatter60[280],scatter80[223],scatter100[179],scatter120[153]]
plt.figure(figsize=(12,9))
plt.scatter(x,scatter20, s=30,marker='.',color='red', label=r'$\theta=20^{\circ}$')
plt.scatter(x,scatter40, s=30,marker='.',color='darkorange', label=r'$\theta=40^{\circ}$')
plt.scatter(x,scatter60, s=30,marker='.',color='gold', label=r'$\theta=60^{\circ}$')
plt.scatter(x,scatter80, s=30,marker='.',color='cyan', label=r'$\theta=80^{\circ}$')
plt.scatter(x,scatter100,s=30,marker='.',color='purple', label=r'$\theta=100^{\circ}$')
plt.scatter(x,scatter120,s=30,marker='.',color='deeppink', label=r'$\theta=120^{\circ}$')
plt.scatter(peak_x,peak_y,s=100,color='none', marker='o', edgecolors='black', label=r'Peaks')

#plt.ylim(0,1.1)

#x_ticks=linspace(0,1,11)
#y_ticks=linspace(0,1.1,12)
#plt.xticks(x_ticks)
#plt.yticks(y_ticks)
plt.tick_params(width=0.5, labelsize=14)
plt.legend(loc='upper right', frameon=False, fontsize=14)
plt.xlim(0,1024)
ax=plt.gca()
ax.set_xlabel(r'x', fontsize=16,x=1,y=1)
ax.set_ylabel(r'N(x)', fontsize=16,x=1,y=1,rotation=0)
#ax.spines['right'].set_color('none')
#ax.spines['top'].set_color('none')
#ax.xaxis.set_ticks_position('bottom')
#ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
#ax.spines['left'].set_position(('data',0))
#ax.set_title('y = x^2',fontsize=14,color='r')
plt.grid()
#x_major_locator=MultipleLocator(0.1)
#y_major_locator=MultipleLocator(50)
#ax.xaxis.set_major_locator(x_major_locator)
#ax.yaxis.set_major_locator(y_major_locator)
plt.savefig('./phyex3_fig.pdf')
plt.show()

# %%
scatter20[0]
# Out:
# 0
